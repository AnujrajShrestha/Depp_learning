# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Embedding,SimpleRNN,Dense

import warnings
warnings.filterwarnings('ignore')

# %%
sentences = [
 "I love this product",
 "This movie made me smile",
 "Service was friendly and quick",
 "Today felt bright and happy",
 "This is the best day",
 "Absolutely fantastic experience",
 "I enjoyed every single moment",
 "Great job, well done",
 "The food tasted delicious",
 "Totally recommend to everyone",
 "Very satisfied with results",
 "This worked better than expected",
 "Amazing quality and value",
 "Such a pleasant surprise",
 "I feel positive about this",
 "I hate this product",
 "This movie bored me",
 "Service was rude and slow",
 "Today was cold and lonely",
 "This is the worst day",
 "Terrible experience overall",
 "I regret buying this",
 "Very disappointed with results",
 "The food tasted awful",
 "Do not recommend this",
 "It broke after one use",
 "Not worth the money",
 "Utterly frustrating and annoying",
 "I feel negative about this",
 "Such a waste of time",
]
labels = [1]*15 + [0]*15
labels = np.array(labels)

# %%
vocab_size=2000
tokenizer=Tokenizer(num_words=vocab_size,oov_token='<OOV>')
tokenizer.fit_on_texts(sentences)
seqs= tokenizer.texts_to_sequences(sentences)
max= max(len(s) for s in seqs)
X= pad_sequences(seqs,maxlen=max,padding='post')
y=labels

# %%
X[0]
# Out:
# array([ 3, 26,  2,  7,  0], dtype=int32)

# %%
embed_dim= 16
rnn_units= 8
inp=Input(shape=(max,),dtype='int32',name='input')
x= Embedding(input_dim=vocab_size,output_dim=embed_dim,name='embedding',mask_zero=True)(inp)
rnn= SimpleRNN(units=rnn_units,return_sequences=False,return_state=False,name='simple_rnn')
x_last= rnn(x)
out= Dense(1,activation='sigmoid',name='out')(x_last)
model= Model(inputs=inp,outputs=out)
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 5)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 5, 16)     │     32,000 │ input[0][0]       │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_4         │ (None, 5)         │          0 │ input[0][0]       │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ simple_rnn          │ (None, 8)         │        200 │ embedding[0][0],  │
# │ (SimpleRNN)         │                   │            │ not_equal_4[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out (Dense)         │ (None, 1)         │          9 │ simple_rnn[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 32,209 (125.82 KB)
#  Trainable params: 32,209 (125.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=25,batch_size=8,verbose=1)
# Out:
# Epoch 1/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3667 - loss: 0.7075
# Epoch 2/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5000 - loss: 0.6901
# Epoch 3/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6667 - loss: 0.6759
# Epoch 4/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6667 - loss: 0.6620
# Epoch 5/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8000 - loss: 0.6488
# Epoch 6/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8333 - loss: 0.6339
# Epoch 7/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9333 - loss: 0.6186
# Epoch 8/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9333 - loss: 0.6033
# Epoch 9/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5844
# Epoch 10/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5643
# Epoch 11/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.5432
# Epoch 12/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.5184
# Epoch 13/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4947
# Epoch 14/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4683
# Epoch 15/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4404
# Epoch 16/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4123
# Epoch 17/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.3828
# Epoch 18/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.3552
# Epoch 19/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.3267
# Epoch 20/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.3001
# Epoch 21/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2751
# Epoch 22/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2512
# Epoch 23/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2291
# Epoch 24/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2085
# Epoch 25/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1913

# %%
from tensorflow.keras.layers import SimpleRNN as SRNN
seq_inp = Input(shape=(max,), dtype='int32')
seq_emb = model.get_layer('embedding')(seq_inp)  # reuse trained embedding

# Create RNN with return_sequences=True
rnn_seq = SRNN(units=rnn_units, return_sequences=True, name='rnn_seq')

# DO NOT CALL build() manually
seq_hidden = rnn_seq(seq_emb)  # builds automatically

# Copy trained RNN weights
try:
    trained_weights = model.get_layer('simple_rnn').get_weights()
    rnn_seq.set_weights(trained_weights)
    print("Copied RNN weights into sequence-inspection RNN.")
except Exception as e:
    print("Could not copy weights automatically:", e)

inspect_model = Model(inputs=seq_inp, outputs=seq_hidden)

# Inspect
idx = 0
example_seq = X[idx:idx+1]  # shape (1, maxlen)
hidden_seq = inspect_model.predict(example_seq)

print("Sentence:", sentences[idx])
print("Token ids:", example_seq)
print("Hidden states per timestep shape:", hidden_seq.shape)
print("Hidden states (timesteps x units):")
print(np.round(hidden_seq[0], 3))
# Out:
# Copied RNN weights into sequence-inspection RNN.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Sentence: I love this product
# Token ids: [[ 3 26  2  7  0]]
# Hidden states per timestep shape: (1, 5, 8)
# Hidden states (timesteps x units):
# [[-0.079  0.076 -0.024  0.012  0.011 -0.056  0.068  0.025]
#  [-0.007 -0.099  0.06  -0.172 -0.018 -0.281  0.147  0.105]
#  [-0.05   0.055 -0.267 -0.002 -0.208  0.048 -0.306  0.349]
#  [-0.254 -0.31   0.325 -0.134 -0.288 -0.28   0.198 -0.352]
#  [-0.254 -0.31   0.325 -0.134 -0.288 -0.28   0.198 -0.352]]
